# %%
import logging
import pandas as pd
import numpy as np
import json
import zipfile
import xgboost as xgb
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import optuna
from optuna.samplers import TPESampler

def add_engineered_features(df):
    # Handle zero division
    df['guests_per_room'] = df['guests'] / df['rooms'].replace(0, np.nan)

    # Create a binary feature for "apartment" in name
    if "name" in df.columns:
        df["name"] = df["name"].astype(str).fillna("")
        df["is_studio"] = df["name"].str.lower().str.contains("studio|wifi|residence|cosy|courtyard|train").astype(int)

    # Generate interaction term between lat and lon
    if "lat" in df.columns and "lon" in df.columns:
        df["lat_lon_interaction"] = df["lat"] * df["lon"]
        city_center_lat, city_center_lon = df["lat"].mean(), df["lon"].mean()

    return df

def baseline():
    logging.info("Reading train and test files")
    train = pd.read_json("train.json", orient='records')
    test = pd.read_json("test.json", orient='records')
    train, valid = train_test_split(train, test_size=1/3, random_state=123)

    # Apply feature engineering
    train = add_engineered_features(train)
    valid = add_engineered_features(valid)
    test = add_engineered_features(test)

    preprocess = ColumnTransformer(
        transformers=[
        ("lat", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat"]),
        ("lon", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lon"]),
        ("lat_lon_interaction", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat_lon_interaction"]),
        ("min_nights", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["min_nights"]),
        ("num_reviews", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["num_reviews"]),
        ("guests", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests"]),
        ("cancellation", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
        ]), ["cancellation"]),
        ("guests_per_room", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests_per_room"]),
        ("rating", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["rating"]),
        ("bathrooms", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["bathrooms"]),
        ("listing_type", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), ["listing_type"]),
        ("room_type", Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('encoder', OneHotEncoder(handle_unknown='ignore'))
            ]), ["room_type"]),
        ("is_studio", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["is_studio"]),

    ],
    remainder='drop'
    )

    label = 'revenue'
    
    # Preprocess the data once
    X_train = preprocess.fit_transform(train.drop([label], axis=1))
    y_train = np.log1p(train[label].values)
    X_valid = preprocess.transform(valid.drop([label], axis=1))
    y_valid = np.log1p(valid[label].values)
    X_test = preprocess.transform(test)

    # Optuna hyperparameter tuning for XGBoost
    logging.info("Starting Optuna tuning for XGBoost")
    
    def objective_xgb(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 300),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'objective': 'reg:squarederror',
            'random_state': 123,
            'verbosity': 0
        }
        
        model = xgb.XGBRegressor(**params)
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], verbose=False)
        
        pred = np.expm1(model.predict(X_valid))
        mae = mean_absolute_error(valid[label], pred)
        return mae
    
    study_xgb = optuna.create_study(direction='minimize', sampler=TPESampler(seed=123))
    study_xgb.optimize(objective_xgb, n_trials=50, show_progress_bar=True)
    
    logging.info(f"Best XGBoost MAE: {study_xgb.best_value:.3f}")
    logging.info(f"Best XGBoost params: {study_xgb.best_params}")
    
    # Optuna hyperparameter tuning for CatBoost
    logging.info("Starting Optuna tuning for CatBoost")
    
    def objective_catboost(trial):
        params = {
            'iterations': trial.suggest_int('iterations', 100, 500),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'depth': trial.suggest_int('depth', 4, 10),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
            'min_child_samples': trial.suggest_int('min_child_samples', 1, 10),
            'random_state': 123,
            'verbose': False
        }
        
        model = CatBoostRegressor(**params)
        model.fit(X_train, y_train, eval_set=(X_valid, y_valid), verbose=False)
        
        pred = np.expm1(model.predict(X_valid))
        mae = mean_absolute_error(valid[label], pred)
        return mae
    
    study_catboost = optuna.create_study(direction='minimize', sampler=TPESampler(seed=123))
    study_catboost.optimize(objective_catboost, n_trials=50, show_progress_bar=True)
    
    logging.info(f"Best CatBoost MAE: {study_catboost.best_value:.3f}")
    logging.info(f"Best CatBoost params: {study_catboost.best_params}")
    
    # Train best models
    logging.info("Training best models on full training data")
    
    best_xgb_params = study_xgb.best_params.copy()
    best_xgb_params.update({'objective': 'reg:squarederror', 'random_state': 123, 'verbosity': 0})
    best_xgb_model = xgb.XGBRegressor(**best_xgb_params)
    best_xgb_model.fit(X_train, y_train)
    
    best_catboost_params = study_catboost.best_params.copy()
    best_catboost_params.update({'random_state': 123, 'verbose': False})
    best_catboost_model = CatBoostRegressor(**best_catboost_params)
    best_catboost_model.fit(X_train, y_train)
    
    # Generate predictions
    xgb_pred_valid = np.expm1(best_xgb_model.predict(X_valid))
    catboost_pred_valid = np.expm1(best_catboost_model.predict(X_valid))
    
    xgb_pred_test = np.expm1(best_xgb_model.predict(X_test))
    catboost_pred_test = np.expm1(best_catboost_model.predict(X_test))
    
    # Test different ensemble weights
    logging.info("\n" + "="*60)
    logging.info("Testing different ensemble strategies")
    logging.info("="*60)
    
    ensemble_strategies = {
        'XGBoost only': (1.0, 0.0),
        'CatBoost only': (0.0, 1.0),
        'XGBoost dominant (0.7/0.3)': (0.7, 0.3),
        'Balanced (0.5/0.5)': (0.5, 0.5),
        'CatBoost dominant (0.3/0.7)': (0.3, 0.7)
    }
    
    results = []
    best_strategy = None
    best_mae = float('inf')
    
    for strategy_name, (xgb_weight, catboost_weight) in ensemble_strategies.items():
        ensemble_pred_valid = xgb_weight * xgb_pred_valid + catboost_weight * catboost_pred_valid
        
        mae = mean_absolute_error(valid[label], ensemble_pred_valid)
        r2 = r2_score(valid[label], ensemble_pred_valid)
        rmse = np.sqrt(mean_squared_error(valid[label], ensemble_pred_valid))
        
        results.append({
            'strategy': strategy_name,
            'xgb_weight': xgb_weight,
            'catboost_weight': catboost_weight,
            'mae': mae,
            'r2': r2,
            'rmse': rmse
        })
        
        logging.info(f"\n{strategy_name}:")
        logging.info(f"  XGB weight: {xgb_weight:.1f}, CatBoost weight: {catboost_weight:.1f}")
        logging.info(f"  MAE: {mae:.3f}")
        logging.info(f"  R²: {r2:.4f}")
        logging.info(f"  RMSE: {rmse:.2f}")
        
        if mae < best_mae:
            best_mae = mae
            best_strategy = strategy_name
            best_weights = (xgb_weight, catboost_weight)
    
    logging.info("\n" + "="*60)
    logging.info(f"Best strategy: {best_strategy} with MAE: {best_mae:.3f}")
    logging.info("="*60)
    
    # Use best ensemble for final predictions
    best_xgb_weight, best_catboost_weight = best_weights
    final_pred_test = best_xgb_weight * xgb_pred_test + best_catboost_weight * catboost_pred_test
    
    test[label] = final_pred_test
    predicted = test[['revenue']].to_dict(orient='records')

    with zipfile.ZipFile("baseline.zip", "w", zipfile.ZIP_DEFLATED) as zipf:
        zipf.writestr("predicted.json", json.dumps(predicted, indent=2))
    
    # Save results summary
    results_df = pd.DataFrame(results)
    results_df.to_csv("ensemble_comparison.csv", index=False)
    logging.info("\nEnsemble comparison saved to 'ensemble_comparison.csv'")
    
    print(f"\nFinal Results (Best Strategy: {best_strategy}):")
    print(f"MAE: {best_mae:.3f}")
    print(f"R²: {results_df[results_df['strategy'] == best_strategy]['r2'].values[0]:.4f}")
    print(f"RMSE: {results_df[results_df['strategy'] == best_strategy]['rmse'].values[0]:.2f}")

if __name__ == '__main__':
    logging.getLogger().setLevel(logging.INFO)
    baseline()
# Out:
# INFO:root:Reading train and test files
# INFO:root:Starting Optuna tuning for XGBoost
# [I 2025-12-02 17:24:57,751] A new study created in memory with name: no-name-f5b7b739-bb1d-4628-9c18-6f6896572adc
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 17:24:59,085] Trial 0 finished with value: 9532.935546875 and parameters: {'n_estimators': 239, 'learning_rate': 0.02646442689360642, 'max_depth': 4, 'subsample': 0.7756573845414456, 'colsample_bytree': 0.8597344848927815, 'min_child_weight': 3, 'gamma': 4.9038209919230775}. Best is trial 0 with value: 9532.935546875.
# [I 2025-12-02 17:25:00,339] Trial 1 finished with value: 8667.4912109375 and parameters: {'n_estimators': 237, 'learning_rate': 0.051332773974241, 'max_depth': 6, 'subsample': 0.6715890080754348, 'colsample_bytree': 0.8645248536920208, 'min_child_weight': 4, 'gamma': 0.29838948304784174}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:01,114] Trial 2 finished with value: 8990.8515625 and parameters: {'n_estimators': 180, 'learning_rate': 0.12305767336794743, 'max_depth': 4, 'subsample': 0.5877258780737462, 'colsample_bytree': 0.7657756869209191, 'min_child_weight': 4, 'gamma': 3.1720047927566055}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:02,339] Trial 3 finished with value: 8711.7724609375 and parameters: {'n_estimators': 270, 'learning_rate': 0.11751907337909233, 'max_depth': 7, 'subsample': 0.8612216912851107, 'colsample_bytree': 0.6614794569265892, 'min_child_weight': 3, 'gamma': 1.141316154394778}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:03,109] Trial 4 finished with value: 9249.66015625 and parameters: {'n_estimators': 159, 'learning_rate': 0.0855122322823435, 'max_depth': 3, 'subsample': 0.7168505863397641, 'colsample_bytree': 0.7154313816648219, 'min_child_weight': 4, 'gamma': 2.1291514514791396}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:04,292] Trial 5 finished with value: 8791.888671875 and parameters: {'n_estimators': 162, 'learning_rate': 0.042635619478693695, 'max_depth': 10, 'subsample': 0.9720800091019398, 'colsample_bytree': 0.7509183379421682, 'min_child_weight': 5, 'gamma': 0.5780919753964786}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:05,180] Trial 6 finished with value: 9033.4384765625 and parameters: {'n_estimators': 163, 'learning_rate': 0.040996673076469745, 'max_depth': 9, 'subsample': 0.6252276826982534, 'colsample_bytree': 0.7415171321313522, 'min_child_weight': 7, 'gamma': 2.597425596299047}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:06,592] Trial 7 finished with value: 9249.8876953125 and parameters: {'n_estimators': 223, 'learning_rate': 0.015072426213243858, 'max_depth': 9, 'subsample': 0.8015300642054637, 'colsample_bytree': 0.7725340032332324, 'min_child_weight': 3, 'gamma': 1.5206039451359206}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:07,573] Trial 8 finished with value: 9090.044921875 and parameters: {'n_estimators': 183, 'learning_rate': 0.10147611734818487, 'max_depth': 10, 'subsample': 0.7552111687390055, 'colsample_bytree': 0.8346568914811361, 'min_child_weight': 5, 'gamma': 3.1245175104779994}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:08,752] Trial 9 finished with value: 9053.1015625 and parameters: {'n_estimators': 235, 'learning_rate': 0.17548577514059563, 'max_depth': 3, 'subsample': 0.8818414207216692, 'colsample_bytree': 0.6218331872684371, 'min_child_weight': 2, 'gamma': 2.8622847874573654}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:09,616] Trial 10 finished with value: 9325.662109375 and parameters: {'n_estimators': 119, 'learning_rate': 0.28898198392195806, 'max_depth': 6, 'subsample': 0.5040305717020104, 'colsample_bytree': 0.994054244657564, 'min_child_weight': 1, 'gamma': 0.019190721168773184}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:11,214] Trial 11 finished with value: 8680.0390625 and parameters: {'n_estimators': 291, 'learning_rate': 0.06602067339892469, 'max_depth': 7, 'subsample': 0.9257336575871629, 'colsample_bytree': 0.5204920216297158, 'min_child_weight': 6, 'gamma': 1.0045753499368093}. Best is trial 1 with value: 8667.4912109375.
# [I 2025-12-02 17:25:12,694] Trial 12 finished with value: 8584.7265625 and parameters: {'n_estimators': 300, 'learning_rate': 0.06182214040761689, 'max_depth': 6, 'subsample': 0.6767984108313557, 'colsample_bytree': 0.518100774887358, 'min_child_weight': 7, 'gamma': 0.014547177548123957}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:14,192] Trial 13 finished with value: 8887.1044921875 and parameters: {'n_estimators': 293, 'learning_rate': 0.023920211026432672, 'max_depth': 6, 'subsample': 0.6800062881915976, 'colsample_bytree': 0.5011428747102034, 'min_child_weight': 7, 'gamma': 0.032333703606991074}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:15,454] Trial 14 finished with value: 10247.07421875 and parameters: {'n_estimators': 258, 'learning_rate': 0.010460073413213658, 'max_depth': 5, 'subsample': 0.6396458301362229, 'colsample_bytree': 0.9449350856793115, 'min_child_weight': 5, 'gamma': 4.0185708623985805}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:16,480] Trial 15 finished with value: 8803.9794921875 and parameters: {'n_estimators': 213, 'learning_rate': 0.050130912623177926, 'max_depth': 8, 'subsample': 0.5298637030215211, 'colsample_bytree': 0.5843894759236903, 'min_child_weight': 6, 'gamma': 1.9135008312812347}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:17,764] Trial 16 finished with value: 8988.66015625 and parameters: {'n_estimators': 269, 'learning_rate': 0.028765906434276678, 'max_depth': 5, 'subsample': 0.6872612428478517, 'colsample_bytree': 0.8818345187279202, 'min_child_weight': 6, 'gamma': 0.6395908884185322}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:19,140] Trial 17 finished with value: 8640.046875 and parameters: {'n_estimators': 298, 'learning_rate': 0.06900518911388019, 'max_depth': 5, 'subsample': 0.6011737205312007, 'colsample_bytree': 0.9213278724624001, 'min_child_weight': 2, 'gamma': 0.4890675103263633}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:20,461] Trial 18 finished with value: 8827.333984375 and parameters: {'n_estimators': 297, 'learning_rate': 0.18427953905394884, 'max_depth': 5, 'subsample': 0.5743672624322057, 'colsample_bytree': 0.9432358972978485, 'min_child_weight': 1, 'gamma': 1.2075256052520706}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:21,013] Trial 19 finished with value: 9192.32421875 and parameters: {'n_estimators': 115, 'learning_rate': 0.07290734998012167, 'max_depth': 4, 'subsample': 0.6026821173785313, 'colsample_bytree': 0.6744709016847691, 'min_child_weight': 2, 'gamma': 1.8510107838142673}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:22,467] Trial 20 finished with value: 8639.2666015625 and parameters: {'n_estimators': 260, 'learning_rate': 0.035964568846135095, 'max_depth': 8, 'subsample': 0.548914876844734, 'colsample_bytree': 0.5693797758476834, 'min_child_weight': 2, 'gamma': 0.7352313469550549}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:24,002] Trial 21 finished with value: 8634.4091796875 and parameters: {'n_estimators': 270, 'learning_rate': 0.03627694648537189, 'max_depth': 8, 'subsample': 0.5424775351835627, 'colsample_bytree': 0.5538548029988598, 'min_child_weight': 2, 'gamma': 0.6996214726641101}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:25,477] Trial 22 finished with value: 8891.65234375 and parameters: {'n_estimators': 261, 'learning_rate': 0.020166292456715234, 'max_depth': 8, 'subsample': 0.5443054043348866, 'colsample_bytree': 0.5667951316824054, 'min_child_weight': 1, 'gamma': 0.8687482632562272}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:26,917] Trial 23 finished with value: 8689.4833984375 and parameters: {'n_estimators': 275, 'learning_rate': 0.039459897634132594, 'max_depth': 8, 'subsample': 0.5459978239318256, 'colsample_bytree': 0.552654854773666, 'min_child_weight': 2, 'gamma': 1.4723278175128107}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:28,260] Trial 24 finished with value: 8690.970703125 and parameters: {'n_estimators': 254, 'learning_rate': 0.033315334568122655, 'max_depth': 7, 'subsample': 0.5057966741459444, 'colsample_bytree': 0.6087278536212772, 'min_child_weight': 3, 'gamma': 0.28289331894632413}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:29,827] Trial 25 finished with value: 8900.078125 and parameters: {'n_estimators': 279, 'learning_rate': 0.019799788838457632, 'max_depth': 9, 'subsample': 0.7251417706630425, 'colsample_bytree': 0.5382081408474991, 'min_child_weight': 2, 'gamma': 1.4914782313282613}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:31,045] Trial 26 finished with value: 9516.9208984375 and parameters: {'n_estimators': 207, 'learning_rate': 0.014452619612198974, 'max_depth': 8, 'subsample': 0.6429687280552345, 'colsample_bytree': 0.633831679083076, 'min_child_weight': 1, 'gamma': 0.9237821821959967}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:32,975] Trial 27 finished with value: 8682.767578125 and parameters: {'n_estimators': 247, 'learning_rate': 0.03306586987236586, 'max_depth': 9, 'subsample': 0.5632046281339891, 'colsample_bytree': 0.5726202646887514, 'min_child_weight': 3, 'gamma': 0.015038767600478451}. Best is trial 12 with value: 8584.7265625.
# [I 2025-12-02 17:25:34,312] Trial 28 finished with value: 8584.4443359375 and parameters: {'n_estimators': 283, 'learning_rate': 0.05776332681502378, 'max_depth': 7, 'subsample': 0.818841350755811, 'colsample_bytree': 0.5006073012106684, 'min_child_weight': 7, 'gamma': 0.702996849015657}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:35,564] Trial 29 finished with value: 8908.6123046875 and parameters: {'n_estimators': 282, 'learning_rate': 0.06134246154396993, 'max_depth': 7, 'subsample': 0.8045599441880774, 'colsample_bytree': 0.5120909418709655, 'min_child_weight': 7, 'gamma': 2.1971842648623694}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:36,629] Trial 30 finished with value: 9192.224609375 and parameters: {'n_estimators': 225, 'learning_rate': 0.052716846958795874, 'max_depth': 6, 'subsample': 0.836384886835861, 'colsample_bytree': 0.5393342713328583, 'min_child_weight': 6, 'gamma': 4.532777294952643}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:38,228] Trial 31 finished with value: 8677.458984375 and parameters: {'n_estimators': 283, 'learning_rate': 0.027263490217919347, 'max_depth': 8, 'subsample': 0.781825126435599, 'colsample_bytree': 0.5965546888126264, 'min_child_weight': 7, 'gamma': 0.7176662885976735}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:39,467] Trial 32 finished with value: 8614.12890625 and parameters: {'n_estimators': 246, 'learning_rate': 0.04852761526061991, 'max_depth': 7, 'subsample': 0.7245034350197797, 'colsample_bytree': 0.5014028444883428, 'min_child_weight': 7, 'gamma': 0.38754673791972266}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:40,636] Trial 33 finished with value: 8643.5556640625 and parameters: {'n_estimators': 235, 'learning_rate': 0.051637885121289764, 'max_depth': 7, 'subsample': 0.713369540243668, 'colsample_bytree': 0.5012961398270146, 'min_child_weight': 7, 'gamma': 0.2166452681661752}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:41,937] Trial 34 finished with value: 8612.8662109375 and parameters: {'n_estimators': 270, 'learning_rate': 0.08817562148889928, 'max_depth': 6, 'subsample': 0.7587964494044752, 'colsample_bytree': 0.5417833610151012, 'min_child_weight': 6, 'gamma': 0.3953522740237039}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:43,126] Trial 35 finished with value: 8628.5966796875 and parameters: {'n_estimators': 244, 'learning_rate': 0.08913501606747624, 'max_depth': 6, 'subsample': 0.7538037561348394, 'colsample_bytree': 0.654546622680647, 'min_child_weight': 6, 'gamma': 0.37328986772057515}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:44,383] Trial 36 finished with value: 8724.9716796875 and parameters: {'n_estimators': 287, 'learning_rate': 0.13736500597335988, 'max_depth': 6, 'subsample': 0.8359444848514227, 'colsample_bytree': 0.5331915949406785, 'min_child_weight': 7, 'gamma': 1.25087335529188}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:45,589] Trial 37 finished with value: 8674.2900390625 and parameters: {'n_estimators': 272, 'learning_rate': 0.07973637520024329, 'max_depth': 4, 'subsample': 0.7263166511375982, 'colsample_bytree': 0.8078843561247073, 'min_child_weight': 6, 'gamma': 0.37626562891435394}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:46,554] Trial 38 finished with value: 8676.60546875 and parameters: {'n_estimators': 194, 'learning_rate': 0.11013066595038519, 'max_depth': 7, 'subsample': 0.8983762028489722, 'colsample_bytree': 0.6961453300074979, 'min_child_weight': 7, 'gamma': 0.2759297044378187}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:47,657] Trial 39 finished with value: 9076.73046875 and parameters: {'n_estimators': 247, 'learning_rate': 0.0456989448137851, 'max_depth': 6, 'subsample': 0.7748511636288442, 'colsample_bytree': 0.5258929219501698, 'min_child_weight': 5, 'gamma': 3.79418251146769}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:48,358] Trial 40 finished with value: 8742.5166015625 and parameters: {'n_estimators': 135, 'learning_rate': 0.09017360520910787, 'max_depth': 5, 'subsample': 0.697350365097819, 'colsample_bytree': 0.6007344133233734, 'min_child_weight': 7, 'gamma': 1.264455205924287}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:49,562] Trial 41 finished with value: 8591.6259765625 and parameters: {'n_estimators': 247, 'learning_rate': 0.09135549302627717, 'max_depth': 6, 'subsample': 0.7378267549215229, 'colsample_bytree': 0.6379384436812187, 'min_child_weight': 6, 'gamma': 0.4716202947277798}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:50,959] Trial 42 finished with value: 8799.9853515625 and parameters: {'n_estimators': 300, 'learning_rate': 0.134246442240855, 'max_depth': 7, 'subsample': 0.6638739983999177, 'colsample_bytree': 0.6366260552990256, 'min_child_weight': 6, 'gamma': 0.5471617886756862}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:52,018] Trial 43 finished with value: 8693.208984375 and parameters: {'n_estimators': 224, 'learning_rate': 0.05995583298615223, 'max_depth': 6, 'subsample': 0.8045721065154069, 'colsample_bytree': 0.548556306542422, 'min_child_weight': 6, 'gamma': 1.000157578595251}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:53,409] Trial 44 finished with value: 8687.1494140625 and parameters: {'n_estimators': 263, 'learning_rate': 0.0963674171730246, 'max_depth': 7, 'subsample': 0.7426334263661125, 'colsample_bytree': 0.5020685867700238, 'min_child_weight': 4, 'gamma': 0.19750593802336533}. Best is trial 28 with value: 8584.4443359375.
# [I 2025-12-02 17:25:54,771] Trial 45 finished with value: 8570.2900390625 and parameters: {'n_estimators': 284, 'learning_rate': 0.07921839266514279, 'max_depth': 6, 'subsample': 0.8416129574553262, 'colsample_bytree': 0.5889950837451522, 'min_child_weight': 5, 'gamma': 0.49613522706236707}. Best is trial 45 with value: 8570.2900390625.
# [I 2025-12-02 17:25:56,088] Trial 46 finished with value: 8575.85546875 and parameters: {'n_estimators': 286, 'learning_rate': 0.0796789270585552, 'max_depth': 5, 'subsample': 0.8552257941282035, 'colsample_bytree': 0.5860255002172495, 'min_child_weight': 4, 'gamma': 0.005504686666521709}. Best is trial 45 with value: 8570.2900390625.
# [I 2025-12-02 17:25:57,435] Trial 47 finished with value: 8626.41796875 and parameters: {'n_estimators': 290, 'learning_rate': 0.07550458667772854, 'max_depth': 5, 'subsample': 0.9573499791594478, 'colsample_bytree': 0.71830857333088, 'min_child_weight': 4, 'gamma': 0.0049216611166031255}. Best is trial 45 with value: 8570.2900390625.
# [I 2025-12-02 17:25:58,652] Trial 48 finished with value: 8698.87109375 and parameters: {'n_estimators': 284, 'learning_rate': 0.1721474052709488, 'max_depth': 4, 'subsample': 0.8568715431159806, 'colsample_bytree': 0.6183769298823295, 'min_child_weight': 5, 'gamma': 0.899627765297552}. Best is trial 45 with value: 8570.2900390625.
# INFO:root:Best XGBoost MAE: 8570.290
# INFO:root:Best XGBoost params: {'n_estimators': 284, 'learning_rate': 0.07921839266514279, 'max_depth': 6, 'subsample': 0.8416129574553262, 'colsample_bytree': 0.5889950837451522, 'min_child_weight': 5, 'gamma': 0.49613522706236707}
# INFO:root:Starting Optuna tuning for CatBoost
# [I 2025-12-02 17:26:00,384] A new study created in memory with name: no-name-736213b4-49b4-4b92-9f53-5aee08728d6f
# [I 2025-12-02 17:26:00,372] Trial 49 finished with value: 8610.32421875 and parameters: {'n_estimators': 290, 'learning_rate': 0.05852953011445315, 'max_depth': 5, 'subsample': 0.8883180101123993, 'colsample_bytree': 0.5845202678248725, 'min_child_weight': 4, 'gamma': 0.6101437009053172}. Best is trial 45 with value: 8570.2900390625.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 17:26:04,311] Trial 0 finished with value: 9341.91245836899 and parameters: {'iterations': 379, 'learning_rate': 0.02646442689360642, 'depth': 5, 'subsample': 0.7756573845414456, 'colsample_bylevel': 0.8597344848927815, 'min_child_samples': 5}. Best is trial 0 with value: 9341.91245836899.
# [I 2025-12-02 17:26:10,970] Trial 1 finished with value: 8702.730810960478 and parameters: {'iterations': 493, 'learning_rate': 0.10270144703457969, 'depth': 7, 'subsample': 0.6960587590970753, 'colsample_bylevel': 0.6715890080754348, 'min_child_samples': 8}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:13,846] Trial 2 finished with value: 10304.853250374787 and parameters: {'iterations': 275, 'learning_rate': 0.012250434413464737, 'depth': 6, 'subsample': 0.8689977028660179, 'colsample_bylevel': 0.59124586522675, 'min_child_samples': 2}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:17,881] Trial 3 finished with value: 8730.465542687189 and parameters: {'iterations': 313, 'learning_rate': 0.06103428098763377, 'depth': 8, 'subsample': 0.9247158970388948, 'colsample_bylevel': 0.8622276624303176, 'min_child_samples': 7}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:20,632] Trial 4 finished with value: 9060.459703116361 and parameters: {'iterations': 389, 'learning_rate': 0.0299950421151354, 'depth': 6, 'subsample': 0.6141316154394778, 'colsample_bylevel': 0.6468570231944146, 'min_child_samples': 7}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:22,406] Trial 5 finished with value: 9536.225115211455 and parameters: {'iterations': 136, 'learning_rate': 0.043714872933908244, 'depth': 7, 'subsample': 0.7468425488251531, 'colsample_bylevel': 0.712915145147914, 'min_child_samples': 4}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:29,431] Trial 6 finished with value: 8788.428247358339 and parameters: {'iterations': 270, 'learning_rate': 0.2087584778566798, 'depth': 10, 'subsample': 0.7509183379421682, 'colsample_bylevel': 0.8119764758960556, 'min_child_samples': 2}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:34,980] Trial 7 finished with value: 9037.32656161491 and parameters: {'iterations': 227, 'learning_rate': 0.040996673076469745, 'depth': 10, 'subsample': 0.6252276826982534, 'colsample_bylevel': 0.7415171321313522, 'min_child_samples': 10}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:36,598] Trial 8 finished with value: 8961.962335409862 and parameters: {'iterations': 308, 'learning_rate': 0.08041175317374143, 'depth': 4, 'subsample': 0.9131704002534167, 'colsample_bylevel': 0.8015300642054637, 'min_child_samples': 6}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:38,598] Trial 9 finished with value: 9556.112958676247 and parameters: {'iterations': 237, 'learning_rate': 0.028133468694618996, 'depth': 6, 'subsample': 0.8406503828963983, 'colsample_bylevel': 0.9377284208975875, 'min_child_samples': 6}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:26:44,373] Trial 10 finished with value: 8670.686226021526 and parameters: {'iterations': 494, 'learning_rate': 0.17061297474135645, 'depth': 8, 'subsample': 0.5040305717020104, 'colsample_bylevel': 0.5232420679967529, 'min_child_samples': 10}. Best is trial 10 with value: 8670.686226021526.
# [I 2025-12-02 17:26:49,753] Trial 11 finished with value: 8755.44616414721 and parameters: {'iterations': 488, 'learning_rate': 0.17262399221087987, 'depth': 8, 'subsample': 0.508242789212093, 'colsample_bylevel': 0.5524576083159141, 'min_child_samples': 10}. Best is trial 10 with value: 8670.686226021526.
# [I 2025-12-02 17:26:55,015] Trial 12 finished with value: 8631.273598703692 and parameters: {'iterations': 498, 'learning_rate': 0.10938417515670472, 'depth': 8, 'subsample': 0.5424301878028753, 'colsample_bylevel': 0.5076626450401519, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:01,439] Trial 13 finished with value: 8859.80430061375 and parameters: {'iterations': 433, 'learning_rate': 0.2933605739294752, 'depth': 9, 'subsample': 0.5000193082273358, 'colsample_bylevel': 0.5128684718030214, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:06,084] Trial 14 finished with value: 8669.940138254307 and parameters: {'iterations': 435, 'learning_rate': 0.12654311263948861, 'depth': 8, 'subsample': 0.5611149124908147, 'colsample_bylevel': 0.6052709859262025, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:12,806] Trial 15 finished with value: 8712.359408440001 and parameters: {'iterations': 430, 'learning_rate': 0.11593231531566166, 'depth': 9, 'subsample': 0.5824816396759698, 'colsample_bylevel': 0.5956050030570769, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:19,797] Trial 16 finished with value: 8688.612982279554 and parameters: {'iterations': 429, 'learning_rate': 0.11911601103479805, 'depth': 9, 'subsample': 0.5778500686943457, 'colsample_bylevel': 0.6199373765975499, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:23,983] Trial 17 finished with value: 8697.721405126578 and parameters: {'iterations': 371, 'learning_rate': 0.070657906585717, 'depth': 8, 'subsample': 0.6716479522437346, 'colsample_bylevel': 0.5588863152404462, 'min_child_samples': 4}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:29,286] Trial 18 finished with value: 8726.623332022249 and parameters: {'iterations': 452, 'learning_rate': 0.27416996996327164, 'depth': 7, 'subsample': 0.9835157950003763, 'colsample_bylevel': 0.6824969103765309, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:36,319] Trial 19 finished with value: 8735.633692285428 and parameters: {'iterations': 348, 'learning_rate': 0.1529264267257073, 'depth': 9, 'subsample': 0.5500668034252133, 'colsample_bylevel': 0.5111954668533317, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:40,712] Trial 20 finished with value: 10091.662940972063 and parameters: {'iterations': 462, 'learning_rate': 0.01048825144667307, 'depth': 5, 'subsample': 0.6655464599252309, 'colsample_bylevel': 0.5799221250161635, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:46,630] Trial 21 finished with value: 8704.665159953604 and parameters: {'iterations': 487, 'learning_rate': 0.15840655917890348, 'depth': 8, 'subsample': 0.5419144053730873, 'colsample_bylevel': 0.5009365296061048, 'min_child_samples': 10}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:51,542] Trial 22 finished with value: 8653.861111870508 and parameters: {'iterations': 416, 'learning_rate': 0.09037264026746915, 'depth': 7, 'subsample': 0.55156761974622, 'colsample_bylevel': 0.5442377562167567, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:55,755] Trial 23 finished with value: 8706.329998989228 and parameters: {'iterations': 402, 'learning_rate': 0.07790799771184817, 'depth': 7, 'subsample': 0.616247440883244, 'colsample_bylevel': 0.6314601662689837, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:27:59,521] Trial 24 finished with value: 8652.237512862963 and parameters: {'iterations': 354, 'learning_rate': 0.09926783178866616, 'depth': 7, 'subsample': 0.5576732504527886, 'colsample_bylevel': 0.5626701803968773, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:02,656] Trial 25 finished with value: 8687.614554641375 and parameters: {'iterations': 341, 'learning_rate': 0.09918868986083908, 'depth': 7, 'subsample': 0.6441518001964927, 'colsample_bylevel': 0.555838755247627, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:07,008] Trial 26 finished with value: 8831.029568698681 and parameters: {'iterations': 398, 'learning_rate': 0.05109494501412658, 'depth': 6, 'subsample': 0.7175093150290943, 'colsample_bylevel': 0.5479706882177001, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:09,782] Trial 27 finished with value: 8709.862064131432 and parameters: {'iterations': 354, 'learning_rate': 0.08785787121891221, 'depth': 5, 'subsample': 0.5826044311196895, 'colsample_bylevel': 0.6617982462579854, 'min_child_samples': 1}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:14,859] Trial 28 finished with value: 8734.725619804338 and parameters: {'iterations': 462, 'learning_rate': 0.05494187855584831, 'depth': 7, 'subsample': 0.5404816299205284, 'colsample_bylevel': 0.9820114724503959, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:16,466] Trial 29 finished with value: 10829.15787004591 and parameters: {'iterations': 136, 'learning_rate': 0.016903219589606507, 'depth': 6, 'subsample': 0.8035215362685769, 'colsample_bylevel': 0.7118371969404567, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:19,792] Trial 30 finished with value: 9220.221595751436 and parameters: {'iterations': 413, 'learning_rate': 0.03724437175389131, 'depth': 4, 'subsample': 0.591763762812764, 'colsample_bylevel': 0.5295585251096229, 'min_child_samples': 10}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:25,992] Trial 31 finished with value: 8689.388041674942 and parameters: {'iterations': 454, 'learning_rate': 0.12693380129474513, 'depth': 8, 'subsample': 0.5506819655936719, 'colsample_bylevel': 0.5992047963139706, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:31,231] Trial 32 finished with value: 8691.229749961203 and parameters: {'iterations': 371, 'learning_rate': 0.13168376859388178, 'depth': 8, 'subsample': 0.5336101221193602, 'colsample_bylevel': 0.6159488988393838, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:39,071] Trial 33 finished with value: 8732.99994270758 and parameters: {'iterations': 418, 'learning_rate': 0.09634749490078112, 'depth': 9, 'subsample': 0.6524043969325757, 'colsample_bylevel': 0.5778274284834801, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:43,211] Trial 34 finished with value: 8723.225888568515 and parameters: {'iterations': 329, 'learning_rate': 0.22263048574213107, 'depth': 7, 'subsample': 0.5609211828699937, 'colsample_bylevel': 0.5458724836025101, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:50,270] Trial 35 finished with value: 8654.304212258634 and parameters: {'iterations': 470, 'learning_rate': 0.07027982663958732, 'depth': 8, 'subsample': 0.7062239503835657, 'colsample_bylevel': 0.5839895857274944, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:28:54,842] Trial 36 finished with value: 8687.372339177293 and parameters: {'iterations': 474, 'learning_rate': 0.06918114072752059, 'depth': 6, 'subsample': 0.6918220173830965, 'colsample_bylevel': 0.6776172912050376, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:01,142] Trial 37 finished with value: 8642.891084690236 and parameters: {'iterations': 500, 'learning_rate': 0.06176889544403232, 'depth': 7, 'subsample': 0.7195425237578754, 'colsample_bylevel': 0.5002255651005312, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:05,727] Trial 38 finished with value: 8720.910643305891 and parameters: {'iterations': 383, 'learning_rate': 0.05816789777278846, 'depth': 7, 'subsample': 0.8071281869621333, 'colsample_bylevel': 0.5057491403090354, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:08,774] Trial 39 finished with value: 8955.754810707409 and parameters: {'iterations': 283, 'learning_rate': 0.04676479451185857, 'depth': 7, 'subsample': 0.6051159131156651, 'colsample_bylevel': 0.5343571859646037, 'min_child_samples': 4}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:13,212] Trial 40 finished with value: 9206.693684097314 and parameters: {'iterations': 495, 'learning_rate': 0.02347116200553023, 'depth': 5, 'subsample': 0.7374135593722068, 'colsample_bylevel': 0.8002830754531955, 'min_child_samples': 3}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:19,393] Trial 41 finished with value: 8642.558257742294 and parameters: {'iterations': 500, 'learning_rate': 0.06824656275371456, 'depth': 7, 'subsample': 0.769467412480958, 'colsample_bylevel': 0.5736615278626822, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:24,405] Trial 42 finished with value: 8646.82293689138 and parameters: {'iterations': 447, 'learning_rate': 0.0859837500683791, 'depth': 7, 'subsample': 0.7701292393639125, 'colsample_bylevel': 0.5740825549124637, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:30,158] Trial 43 finished with value: 8862.241829303995 and parameters: {'iterations': 497, 'learning_rate': 0.036627836989962435, 'depth': 6, 'subsample': 0.7845119302748931, 'colsample_bylevel': 0.5721790059563345, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:35,462] Trial 44 finished with value: 8668.87389316469 and parameters: {'iterations': 446, 'learning_rate': 0.06243823991811153, 'depth': 7, 'subsample': 0.8618884252215364, 'colsample_bylevel': 0.6479302456858823, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:29:39,961] Trial 45 finished with value: 8623.602619945632 and parameters: {'iterations': 478, 'learning_rate': 0.104751362586171, 'depth': 6, 'subsample': 0.7684952871916646, 'colsample_bylevel': 0.8619667505985178, 'min_child_samples': 6}. Best is trial 45 with value: 8623.602619945632.
# [I 2025-12-02 17:29:44,621] Trial 46 finished with value: 8632.833180370491 and parameters: {'iterations': 477, 'learning_rate': 0.0827257727338526, 'depth': 6, 'subsample': 0.8314510626888774, 'colsample_bylevel': 0.8845020937717624, 'min_child_samples': 6}. Best is trial 45 with value: 8623.602619945632.
# [I 2025-12-02 17:29:48,197] Trial 47 finished with value: 8607.84617188617 and parameters: {'iterations': 477, 'learning_rate': 0.19654093203091005, 'depth': 5, 'subsample': 0.8369584963585432, 'colsample_bylevel': 0.8893461550583386, 'min_child_samples': 4}. Best is trial 47 with value: 8607.84617188617.
# [I 2025-12-02 17:29:52,675] Trial 48 finished with value: 8662.053763107144 and parameters: {'iterations': 480, 'learning_rate': 0.19855471076785197, 'depth': 5, 'subsample': 0.905733394900148, 'colsample_bylevel': 0.8821178455281118, 'min_child_samples': 4}. Best is trial 47 with value: 8607.84617188617.
# INFO:root:Best CatBoost MAE: 8607.846
# INFO:root:Best CatBoost params: {'iterations': 477, 'learning_rate': 0.19654093203091005, 'depth': 5, 'subsample': 0.8369584963585432, 'colsample_bylevel': 0.8893461550583386, 'min_child_samples': 4}
# INFO:root:Training best models on full training data
# [I 2025-12-02 17:29:54,077] Trial 49 finished with value: 8842.948266704387 and parameters: {'iterations': 161, 'learning_rate': 0.25260953947271864, 'depth': 4, 'subsample': 0.8190487749340074, 'colsample_bylevel': 0.8986161892330974, 'min_child_samples': 3}. Best is trial 47 with value: 8607.84617188617.
# INFO:root:
# ============================================================
# INFO:root:Testing different ensemble strategies
# INFO:root:============================================================
# INFO:root:
# XGBoost only:
# INFO:root:  XGB weight: 1.0, CatBoost weight: 0.0
# INFO:root:  MAE: 8570.291
# INFO:root:  R²: 0.6133
# INFO:root:  RMSE: 15590.82
# INFO:root:
# CatBoost only:
# INFO:root:  XGB weight: 0.0, CatBoost weight: 1.0
# INFO:root:  MAE: 8592.763
# INFO:root:  R²: 0.6254
# INFO:root:  RMSE: 15344.42
# INFO:root:
# XGBoost dominant (0.7/0.3):
# INFO:root:  XGB weight: 0.7, CatBoost weight: 0.3
# INFO:root:  MAE: 8500.458
# INFO:root:  R²: 0.6244
# INFO:root:  RMSE: 15365.57
# INFO:root:
# Balanced (0.5/0.5):
# INFO:root:  XGB weight: 0.5, CatBoost weight: 0.5
# INFO:root:  MAE: 8492.625
# INFO:root:  R²: 0.6282
# INFO:root:  RMSE: 15286.72
# INFO:root:
# CatBoost dominant (0.3/0.7):
# INFO:root:  XGB weight: 0.3, CatBoost weight: 0.7
# INFO:root:  MAE: 8515.900
# INFO:root:  R²: 0.6292
# INFO:root:  RMSE: 15266.04
# INFO:root:
# ============================================================
# INFO:root:Best strategy: Balanced (0.5/0.5) with MAE: 8492.625
# INFO:root:============================================================
# INFO:root:
# Ensemble comparison saved to 'ensemble_comparison.csv'
# Final Results (Best Strategy: Balanced (0.5/0.5)):
# MAE: 8492.625
# R²: 0.6282
# RMSE: 15286.72

# %%
#best
import logging
import pandas as pd
import numpy as np
import json
import zipfile
import xgboost as xgb # Import XGBoost
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np

def add_engineered_features(df):
    # Handle zero division
    df['guests_per_room'] = df['guests'] / df['rooms'].replace(0, np.nan)

    # Create a binary feature for "apartment" in name
    if "name" in df.columns:
        df["name"] = df["name"].astype(str).fillna("")
        df["is_studio"] = df["name"].str.lower().str.contains("studio|wifi|residence|cosy|courtyard|train").astype(int)
    
    # Generate interaction term between lat and lon
    if "lat" in df.columns and "lon" in df.columns:
        df["lat_lon_interaction"] = df["lat"] * df["lon"]
        city_center_lat, city_center_lon = df["lat"].mean(), df["lon"].mean()

    return df

def baseline():
    logging.info("Reading train and test files")
    train = pd.read_json("train.json", orient='records')
    test = pd.read_json("test.json", orient='records')
    train, valid = train_test_split(train, test_size=1/3, random_state=123)

    # Apply feature engineering
    train = add_engineered_features(train)
    valid = add_engineered_features(valid)
    test = add_engineered_features(test)

    preprocess = ColumnTransformer(
        transformers=[
        ("lat", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat"]),
        ("lon", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lon"]),
        ("lat_lon_interaction", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat_lon_interaction"]),
        ("min_nights", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["min_nights"]),
        ("num_reviews", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["num_reviews"]),
        ("guests", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests"]),
        ("cancellation", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
        ]), ["cancellation"]),
        ("guests_per_room", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests_per_room"]),
        ("rating", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["rating"]),
        ("bathrooms", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["bathrooms"]),
        ("listing_type", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), ["listing_type"]),
        ("room_type", Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('encoder', OneHotEncoder(handle_unknown='ignore'))
            ]), ["room_type"]),
        ("is_studio", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["is_studio"]),
        
    ],
    remainder='drop'
    )

    dummy = make_pipeline(preprocess, DummyRegressor())
    xgb_model = make_pipeline(preprocess, xgb.XGBRegressor(
        n_estimators=285, learning_rate=0.1, max_depth=5, subsample=0.6, colsample_bytree=0.7,
        objective='reg:squarederror', random_state=123))

    label = 'revenue'
    for model_name, model in [("mean", dummy), ("xgboost", xgb_model)]:
        logging.info(f"Fitting model {model_name}")
        model.fit(train.drop([label], axis=1), np.log1p(train[label].values))

        for split_name, split in [("train", train), ("valid", valid)]:
            pred = np.expm1(model.predict(split.drop([label], axis=1)))
            mae = mean_absolute_error(split[label], pred)
            logging.info(f"{model_name} {split_name} {mae:.3f}")

    pred_test = np.expm1(xgb_model.predict(test))
    test[label] = pred_test
    predicted = test[['revenue']].to_dict(orient='records')

    with zipfile.ZipFile("baseline.zip", "w", zipfile.ZIP_DEFLATED) as zipf:
        zipf.writestr("predicted.json", json.dumps(predicted, indent=2))

    r2 = r2_score(valid["revenue"], pred)
    rmse = mean_squared_error(valid["revenue"], pred)
    mae = mean_absolute_error(valid["revenue"], pred)

    print(f"R² Score: {r2:.4f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")

if __name__ == '__main__':
    logging.getLogger().setLevel(logging.INFO)
    baseline()
# Out:
# INFO:root:Reading train and test files
# INFO:root:Fitting model mean
# INFO:root:mean train 14798.557
# INFO:root:mean valid 14397.861
# INFO:root:Fitting model xgboost
# INFO:root:xgboost train 7331.454
# INFO:root:xgboost valid 8483.982
# R² Score: 0.6323
# RMSE: 231149520.00
# MAE: 8483.98

# %%
import logging
import pandas as pd
import numpy as np
import json
import zipfile
import xgboost as xgb
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import optuna
from optuna.samplers import TPESampler

def add_engineered_features(df):
    # Handle zero division
    df['guests_per_room'] = df['guests'] / df['rooms'].replace(0, np.nan)

    # Create a binary feature for "apartment" in name
    if "name" in df.columns:
        df["name"] = df["name"].astype(str).fillna("")
        df["is_studio"] = df["name"].str.lower().str.contains("studio|wifi|residence|cosy|courtyard|train").astype(int)
    
    # Generate interaction term between lat and lon
    if "lat" in df.columns and "lon" in df.columns:
        df["lat_lon_interaction"] = df["lat"] * df["lon"]
        city_center_lat, city_center_lon = df["lat"].mean(), df["lon"].mean()

    return df

def baseline():
    logging.info("Reading train and test files")
    train = pd.read_json("train.json", orient='records')
    test = pd.read_json("test.json", orient='records')
    train, valid = train_test_split(train, test_size=1/3, random_state=123)

    # Apply feature engineering
    train = add_engineered_features(train)
    valid = add_engineered_features(valid)
    test = add_engineered_features(test)

    preprocess = ColumnTransformer(
        transformers=[
        ("lat", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat"]),
        ("lon", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lon"]),
        ("lat_lon_interaction", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["lat_lon_interaction"]),
        ("min_nights", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["min_nights"]),
        ("num_reviews", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["num_reviews"]),
        ("guests", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests"]),
        ("cancellation", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
        ]), ["cancellation"]),
        ("guests_per_room", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["guests_per_room"]),
        ("rating", Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))]), ["rating"]),
        ("bathrooms", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["bathrooms"]),
        ("listing_type", Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), ["listing_type"]),
        ("room_type", Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('encoder', OneHotEncoder(handle_unknown='ignore'))
            ]), ["room_type"]),
        ("is_studio", Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]), ["is_studio"]),
        
    ],
    remainder='drop'
    )

    label = 'revenue'
    
    # Train best XGBoost model (with your optimal parameters)
    logging.info("Training XGBoost with best parameters")
    xgb_model = make_pipeline(preprocess, xgb.XGBRegressor(
        n_estimators=285, learning_rate=0.1, max_depth=5, subsample=0.6, colsample_bytree=0.7,
        objective='reg:squarederror', random_state=123))
    
    xgb_model.fit(train.drop([label], axis=1), np.log1p(train[label].values))
    
    xgb_pred_train = np.expm1(xgb_model.predict(train.drop([label], axis=1)))
    xgb_pred_valid = np.expm1(xgb_model.predict(valid.drop([label], axis=1)))
    
    xgb_mae_train = mean_absolute_error(train[label], xgb_pred_train)
    xgb_mae_valid = mean_absolute_error(valid[label], xgb_pred_valid)
    logging.info(f"XGBoost train MAE: {xgb_mae_train:.3f}")
    logging.info(f"XGBoost valid MAE: {xgb_mae_valid:.3f}")
    
    # Preprocess data for CatBoost tuning
    X_train = preprocess.transform(train.drop([label], axis=1))
    y_train = np.log1p(train[label].values)
    X_valid = preprocess.transform(valid.drop([label], axis=1))
    y_valid = np.log1p(valid[label].values)
    
    # Optuna hyperparameter tuning for CatBoost
    logging.info("\nStarting Optuna tuning for CatBoost")
    
    def objective_catboost(trial):
        params = {
            'iterations': trial.suggest_int('iterations', 100, 500),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'depth': trial.suggest_int('depth', 4, 10),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
            'min_child_samples': trial.suggest_int('min_child_samples', 1, 10),
            'random_state': 123,
            'verbose': False
        }
        
        model = CatBoostRegressor(**params)
        model.fit(X_train, y_train, eval_set=(X_valid, y_valid), verbose=False)
        
        pred = np.expm1(model.predict(X_valid))
        mae = mean_absolute_error(valid[label], pred)
        return mae
    
    study_catboost = optuna.create_study(direction='minimize', sampler=TPESampler(seed=123))
    study_catboost.optimize(objective_catboost, n_trials=50, show_progress_bar=True)
    
    logging.info(f"\nBest CatBoost MAE: {study_catboost.best_value:.3f}")
    logging.info(f"Best CatBoost params: {study_catboost.best_params}")
    
    # Train best CatBoost model
    logging.info("\nTraining CatBoost with best parameters")
    best_catboost_params = study_catboost.best_params.copy()
    best_catboost_params.update({'random_state': 123, 'verbose': False})
    
    catboost_model = make_pipeline(preprocess, CatBoostRegressor(**best_catboost_params))
    catboost_model.fit(train.drop([label], axis=1), np.log1p(train[label].values))
    
    catboost_pred_train = np.expm1(catboost_model.predict(train.drop([label], axis=1)))
    catboost_pred_valid = np.expm1(catboost_model.predict(valid.drop([label], axis=1)))
    
    catboost_mae_train = mean_absolute_error(train[label], catboost_pred_train)
    catboost_mae_valid = mean_absolute_error(valid[label], catboost_pred_valid)
    logging.info(f"CatBoost train MAE: {catboost_mae_train:.3f}")
    logging.info(f"CatBoost valid MAE: {catboost_mae_valid:.3f}")
    
    # Test different ensemble weights
    logging.info("\n" + "="*60)
    logging.info("Testing different ensemble strategies")
    logging.info("="*60)
    
    ensemble_strategies = {
        'XGBoost only': (1.0, 0.0),
        'CatBoost only': (0.0, 1.0),
        'XGBoost dominant (0.7/0.3)': (0.7, 0.3),
        'Balanced (0.5/0.5)': (0.5, 0.5),
        'CatBoost dominant (0.3/0.7)': (0.3, 0.7)
    }
    
    results = []
    best_strategy = None
    best_mae = float('inf')
    
    for strategy_name, (xgb_weight, catboost_weight) in ensemble_strategies.items():
        ensemble_pred_valid = xgb_weight * xgb_pred_valid + catboost_weight * catboost_pred_valid
        
        mae = mean_absolute_error(valid[label], ensemble_pred_valid)
        r2 = r2_score(valid[label], ensemble_pred_valid)
        rmse = np.sqrt(mean_squared_error(valid[label], ensemble_pred_valid))
        
        results.append({
            'strategy': strategy_name,
            'xgb_weight': xgb_weight,
            'catboost_weight': catboost_weight,
            'mae': mae,
            'r2': r2,
            'rmse': rmse
        })
        
        logging.info(f"\n{strategy_name}:")
        logging.info(f"  XGB weight: {xgb_weight:.1f}, CatBoost weight: {catboost_weight:.1f}")
        logging.info(f"  MAE: {mae:.3f}")
        logging.info(f"  R²: {r2:.4f}")
        logging.info(f"  RMSE: {rmse:.2f}")
        
        if mae < best_mae:
            best_mae = mae
            best_strategy = strategy_name
            best_weights = (xgb_weight, catboost_weight)
    
    logging.info("\n" + "="*60)
    logging.info(f"Best strategy: {best_strategy} with MAE: {best_mae:.3f}")
    logging.info("="*60)
    
    # Use best ensemble for final predictions
    best_xgb_weight, best_catboost_weight = best_weights
    xgb_pred_test = np.expm1(xgb_model.predict(test))
    catboost_pred_test = np.expm1(catboost_model.predict(test))
    final_pred_test = best_xgb_weight * xgb_pred_test + best_catboost_weight * catboost_pred_test
    
    test[label] = final_pred_test
    predicted = test[['revenue']].to_dict(orient='records')

    with zipfile.ZipFile("baseline.zip", "w", zipfile.ZIP_DEFLATED) as zipf:
        zipf.writestr("predicted.json", json.dumps(predicted, indent=2))
    
    # Save results summary
    results_df = pd.DataFrame(results)
    results_df.to_csv("ensemble_comparison.csv", index=False)
    logging.info("\nEnsemble comparison saved to 'ensemble_comparison.csv'")
    
    print(f"\n{'='*60}")
    print(f"Final Results (Best Strategy: {best_strategy})")
    print(f"{'='*60}")
    print(f"MAE: {best_mae:.3f}")
    print(f"R²: {results_df[results_df['strategy'] == best_strategy]['r2'].values[0]:.4f}")
    print(f"RMSE: {results_df[results_df['strategy'] == best_strategy]['rmse'].values[0]:.2f}")

if __name__ == '__main__':
    logging.getLogger().setLevel(logging.INFO)
    baseline()
# Out:
# INFO:root:Reading train and test files
# INFO:root:Training XGBoost with best parameters
# INFO:root:XGBoost train MAE: 7331.454
# INFO:root:XGBoost valid MAE: 8483.982
# INFO:root:
# Starting Optuna tuning for CatBoost
# [I 2025-12-02 17:36:24,034] A new study created in memory with name: no-name-ba0802d9-ae84-44c1-94c3-6d361ed1d993
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-02 17:36:27,535] Trial 0 finished with value: 9341.91245836899 and parameters: {'iterations': 379, 'learning_rate': 0.02646442689360642, 'depth': 5, 'subsample': 0.7756573845414456, 'colsample_bylevel': 0.8597344848927815, 'min_child_samples': 5}. Best is trial 0 with value: 9341.91245836899.
# [I 2025-12-02 17:36:33,991] Trial 1 finished with value: 8702.730810960478 and parameters: {'iterations': 493, 'learning_rate': 0.10270144703457969, 'depth': 7, 'subsample': 0.6960587590970753, 'colsample_bylevel': 0.6715890080754348, 'min_child_samples': 8}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:36:37,277] Trial 2 finished with value: 10304.853250374787 and parameters: {'iterations': 275, 'learning_rate': 0.012250434413464737, 'depth': 6, 'subsample': 0.8689977028660179, 'colsample_bylevel': 0.59124586522675, 'min_child_samples': 2}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:36:42,695] Trial 3 finished with value: 8730.465542687189 and parameters: {'iterations': 313, 'learning_rate': 0.06103428098763377, 'depth': 8, 'subsample': 0.9247158970388948, 'colsample_bylevel': 0.8622276624303176, 'min_child_samples': 7}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:36:47,143] Trial 4 finished with value: 9060.459703116361 and parameters: {'iterations': 389, 'learning_rate': 0.0299950421151354, 'depth': 6, 'subsample': 0.6141316154394778, 'colsample_bylevel': 0.6468570231944146, 'min_child_samples': 7}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:36:49,316] Trial 5 finished with value: 9536.225115211455 and parameters: {'iterations': 136, 'learning_rate': 0.043714872933908244, 'depth': 7, 'subsample': 0.7468425488251531, 'colsample_bylevel': 0.712915145147914, 'min_child_samples': 4}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:36:57,134] Trial 6 finished with value: 8788.428247358339 and parameters: {'iterations': 270, 'learning_rate': 0.2087584778566798, 'depth': 10, 'subsample': 0.7509183379421682, 'colsample_bylevel': 0.8119764758960556, 'min_child_samples': 2}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:37:03,317] Trial 7 finished with value: 9037.32656161491 and parameters: {'iterations': 227, 'learning_rate': 0.040996673076469745, 'depth': 10, 'subsample': 0.6252276826982534, 'colsample_bylevel': 0.7415171321313522, 'min_child_samples': 10}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:37:05,484] Trial 8 finished with value: 8961.962335409862 and parameters: {'iterations': 308, 'learning_rate': 0.08041175317374143, 'depth': 4, 'subsample': 0.9131704002534167, 'colsample_bylevel': 0.8015300642054637, 'min_child_samples': 6}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:37:07,418] Trial 9 finished with value: 9556.112958676247 and parameters: {'iterations': 237, 'learning_rate': 0.028133468694618996, 'depth': 6, 'subsample': 0.8406503828963983, 'colsample_bylevel': 0.9377284208975875, 'min_child_samples': 6}. Best is trial 1 with value: 8702.730810960478.
# [I 2025-12-02 17:37:14,069] Trial 10 finished with value: 8670.686226021526 and parameters: {'iterations': 494, 'learning_rate': 0.17061297474135645, 'depth': 8, 'subsample': 0.5040305717020104, 'colsample_bylevel': 0.5232420679967529, 'min_child_samples': 10}. Best is trial 10 with value: 8670.686226021526.
# [I 2025-12-02 17:37:19,847] Trial 11 finished with value: 8755.44616414721 and parameters: {'iterations': 488, 'learning_rate': 0.17262399221087987, 'depth': 8, 'subsample': 0.508242789212093, 'colsample_bylevel': 0.5524576083159141, 'min_child_samples': 10}. Best is trial 10 with value: 8670.686226021526.
# [I 2025-12-02 17:37:26,659] Trial 12 finished with value: 8631.273598703692 and parameters: {'iterations': 498, 'learning_rate': 0.10938417515670472, 'depth': 8, 'subsample': 0.5424301878028753, 'colsample_bylevel': 0.5076626450401519, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:37:34,683] Trial 13 finished with value: 8859.80430061375 and parameters: {'iterations': 433, 'learning_rate': 0.2933605739294752, 'depth': 9, 'subsample': 0.5000193082273358, 'colsample_bylevel': 0.5128684718030214, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:37:41,262] Trial 14 finished with value: 8669.940138254307 and parameters: {'iterations': 435, 'learning_rate': 0.12654311263948861, 'depth': 8, 'subsample': 0.5611149124908147, 'colsample_bylevel': 0.6052709859262025, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:37:50,353] Trial 15 finished with value: 8712.359408440001 and parameters: {'iterations': 430, 'learning_rate': 0.11593231531566166, 'depth': 9, 'subsample': 0.5824816396759698, 'colsample_bylevel': 0.5956050030570769, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:37:58,654] Trial 16 finished with value: 8688.612982279554 and parameters: {'iterations': 429, 'learning_rate': 0.11911601103479805, 'depth': 9, 'subsample': 0.5778500686943457, 'colsample_bylevel': 0.6199373765975499, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:04,230] Trial 17 finished with value: 8697.721405126578 and parameters: {'iterations': 371, 'learning_rate': 0.070657906585717, 'depth': 8, 'subsample': 0.6716479522437346, 'colsample_bylevel': 0.5588863152404462, 'min_child_samples': 4}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:10,236] Trial 18 finished with value: 8726.623332022249 and parameters: {'iterations': 452, 'learning_rate': 0.27416996996327164, 'depth': 7, 'subsample': 0.9835157950003763, 'colsample_bylevel': 0.6824969103765309, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:17,486] Trial 19 finished with value: 8735.633692285428 and parameters: {'iterations': 348, 'learning_rate': 0.1529264267257073, 'depth': 9, 'subsample': 0.5500668034252133, 'colsample_bylevel': 0.5111954668533317, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:22,229] Trial 20 finished with value: 10091.662940972063 and parameters: {'iterations': 462, 'learning_rate': 0.01048825144667307, 'depth': 5, 'subsample': 0.6655464599252309, 'colsample_bylevel': 0.5799221250161635, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:29,901] Trial 21 finished with value: 8704.665159953604 and parameters: {'iterations': 487, 'learning_rate': 0.15840655917890348, 'depth': 8, 'subsample': 0.5419144053730873, 'colsample_bylevel': 0.5009365296061048, 'min_child_samples': 10}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:35,313] Trial 22 finished with value: 8653.861111870508 and parameters: {'iterations': 416, 'learning_rate': 0.09037264026746915, 'depth': 7, 'subsample': 0.55156761974622, 'colsample_bylevel': 0.5442377562167567, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:40,147] Trial 23 finished with value: 8706.329998989228 and parameters: {'iterations': 402, 'learning_rate': 0.07790799771184817, 'depth': 7, 'subsample': 0.616247440883244, 'colsample_bylevel': 0.6314601662689837, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:44,363] Trial 24 finished with value: 8652.237512862963 and parameters: {'iterations': 354, 'learning_rate': 0.09926783178866616, 'depth': 7, 'subsample': 0.5576732504527886, 'colsample_bylevel': 0.5626701803968773, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:48,986] Trial 25 finished with value: 8687.614554641375 and parameters: {'iterations': 341, 'learning_rate': 0.09918868986083908, 'depth': 7, 'subsample': 0.6441518001964927, 'colsample_bylevel': 0.555838755247627, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:53,698] Trial 26 finished with value: 8831.029568698681 and parameters: {'iterations': 398, 'learning_rate': 0.05109494501412658, 'depth': 6, 'subsample': 0.7175093150290943, 'colsample_bylevel': 0.5479706882177001, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:38:57,335] Trial 27 finished with value: 8709.862064131432 and parameters: {'iterations': 354, 'learning_rate': 0.08785787121891221, 'depth': 5, 'subsample': 0.5826044311196895, 'colsample_bylevel': 0.6617982462579854, 'min_child_samples': 1}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:02,414] Trial 28 finished with value: 8734.725619804338 and parameters: {'iterations': 462, 'learning_rate': 0.05494187855584831, 'depth': 7, 'subsample': 0.5404816299205284, 'colsample_bylevel': 0.9820114724503959, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:04,262] Trial 29 finished with value: 10829.15787004591 and parameters: {'iterations': 136, 'learning_rate': 0.016903219589606507, 'depth': 6, 'subsample': 0.8035215362685769, 'colsample_bylevel': 0.7118371969404567, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:07,873] Trial 30 finished with value: 9220.221595751436 and parameters: {'iterations': 413, 'learning_rate': 0.03724437175389131, 'depth': 4, 'subsample': 0.591763762812764, 'colsample_bylevel': 0.5295585251096229, 'min_child_samples': 10}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:14,727] Trial 31 finished with value: 8689.388041674942 and parameters: {'iterations': 454, 'learning_rate': 0.12693380129474513, 'depth': 8, 'subsample': 0.5506819655936719, 'colsample_bylevel': 0.5992047963139706, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:20,626] Trial 32 finished with value: 8691.229749961203 and parameters: {'iterations': 371, 'learning_rate': 0.13168376859388178, 'depth': 8, 'subsample': 0.5336101221193602, 'colsample_bylevel': 0.6159488988393838, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:29,469] Trial 33 finished with value: 8732.99994270758 and parameters: {'iterations': 418, 'learning_rate': 0.09634749490078112, 'depth': 9, 'subsample': 0.6524043969325757, 'colsample_bylevel': 0.5778274284834801, 'min_child_samples': 8}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:33,368] Trial 34 finished with value: 8723.225888568515 and parameters: {'iterations': 329, 'learning_rate': 0.22263048574213107, 'depth': 7, 'subsample': 0.5609211828699937, 'colsample_bylevel': 0.5458724836025101, 'min_child_samples': 9}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:40,756] Trial 35 finished with value: 8654.304212258634 and parameters: {'iterations': 470, 'learning_rate': 0.07027982663958732, 'depth': 8, 'subsample': 0.7062239503835657, 'colsample_bylevel': 0.5839895857274944, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:45,826] Trial 36 finished with value: 8687.372339177293 and parameters: {'iterations': 474, 'learning_rate': 0.06918114072752059, 'depth': 6, 'subsample': 0.6918220173830965, 'colsample_bylevel': 0.6776172912050376, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:51,761] Trial 37 finished with value: 8642.891084690236 and parameters: {'iterations': 500, 'learning_rate': 0.06176889544403232, 'depth': 7, 'subsample': 0.7195425237578754, 'colsample_bylevel': 0.5002255651005312, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:56,559] Trial 38 finished with value: 8720.910643305891 and parameters: {'iterations': 383, 'learning_rate': 0.05816789777278846, 'depth': 7, 'subsample': 0.8071281869621333, 'colsample_bylevel': 0.5057491403090354, 'min_child_samples': 7}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:39:59,192] Trial 39 finished with value: 8955.754810707409 and parameters: {'iterations': 283, 'learning_rate': 0.04676479451185857, 'depth': 7, 'subsample': 0.6051159131156651, 'colsample_bylevel': 0.5343571859646037, 'min_child_samples': 4}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:04,169] Trial 40 finished with value: 9206.693684097314 and parameters: {'iterations': 495, 'learning_rate': 0.02347116200553023, 'depth': 5, 'subsample': 0.7374135593722068, 'colsample_bylevel': 0.8002830754531955, 'min_child_samples': 3}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:10,599] Trial 41 finished with value: 8642.558257742294 and parameters: {'iterations': 500, 'learning_rate': 0.06824656275371456, 'depth': 7, 'subsample': 0.769467412480958, 'colsample_bylevel': 0.5736615278626822, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:16,108] Trial 42 finished with value: 8646.82293689138 and parameters: {'iterations': 447, 'learning_rate': 0.0859837500683791, 'depth': 7, 'subsample': 0.7701292393639125, 'colsample_bylevel': 0.5740825549124637, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:21,158] Trial 43 finished with value: 8862.241829303995 and parameters: {'iterations': 497, 'learning_rate': 0.036627836989962435, 'depth': 6, 'subsample': 0.7845119302748931, 'colsample_bylevel': 0.5721790059563345, 'min_child_samples': 6}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:26,857] Trial 44 finished with value: 8668.87389316469 and parameters: {'iterations': 446, 'learning_rate': 0.06243823991811153, 'depth': 7, 'subsample': 0.8618884252215364, 'colsample_bylevel': 0.6479302456858823, 'min_child_samples': 5}. Best is trial 12 with value: 8631.273598703692.
# [I 2025-12-02 17:40:31,823] Trial 45 finished with value: 8623.602619945632 and parameters: {'iterations': 478, 'learning_rate': 0.104751362586171, 'depth': 6, 'subsample': 0.7684952871916646, 'colsample_bylevel': 0.8619667505985178, 'min_child_samples': 6}. Best is trial 45 with value: 8623.602619945632.
# [I 2025-12-02 17:40:37,106] Trial 46 finished with value: 8632.833180370491 and parameters: {'iterations': 477, 'learning_rate': 0.0827257727338526, 'depth': 6, 'subsample': 0.8314510626888774, 'colsample_bylevel': 0.8845020937717624, 'min_child_samples': 6}. Best is trial 45 with value: 8623.602619945632.
# [I 2025-12-02 17:40:41,987] Trial 47 finished with value: 8607.84617188617 and parameters: {'iterations': 477, 'learning_rate': 0.19654093203091005, 'depth': 5, 'subsample': 0.8369584963585432, 'colsample_bylevel': 0.8893461550583386, 'min_child_samples': 4}. Best is trial 47 with value: 8607.84617188617.
# [I 2025-12-02 17:40:47,906] Trial 48 finished with value: 8662.053763107144 and parameters: {'iterations': 480, 'learning_rate': 0.19855471076785197, 'depth': 5, 'subsample': 0.905733394900148, 'colsample_bylevel': 0.8821178455281118, 'min_child_samples': 4}. Best is trial 47 with value: 8607.84617188617.
# INFO:root:
# Best CatBoost MAE: 8607.846
# INFO:root:Best CatBoost params: {'iterations': 477, 'learning_rate': 0.19654093203091005, 'depth': 5, 'subsample': 0.8369584963585432, 'colsample_bylevel': 0.8893461550583386, 'min_child_samples': 4}
# INFO:root:
# Training CatBoost with best parameters
# [I 2025-12-02 17:40:49,968] Trial 49 finished with value: 8842.948266704387 and parameters: {'iterations': 161, 'learning_rate': 0.25260953947271864, 'depth': 4, 'subsample': 0.8190487749340074, 'colsample_bylevel': 0.8986161892330974, 'min_child_samples': 3}. Best is trial 47 with value: 8607.84617188617.
# INFO:root:CatBoost train MAE: 7644.097
# INFO:root:CatBoost valid MAE: 8592.763
# INFO:root:
# ============================================================
# INFO:root:Testing different ensemble strategies
# INFO:root:============================================================
# INFO:root:
# XGBoost only:
# INFO:root:  XGB weight: 1.0, CatBoost weight: 0.0
# INFO:root:  MAE: 8483.982
# INFO:root:  R²: 0.6323
# INFO:root:  RMSE: 15203.60
# INFO:root:
# CatBoost only:
# INFO:root:  XGB weight: 0.0, CatBoost weight: 1.0
# INFO:root:  MAE: 8592.763
# INFO:root:  R²: 0.6254
# INFO:root:  RMSE: 15344.42
# INFO:root:
# XGBoost dominant (0.7/0.3):
# INFO:root:  XGB weight: 0.7, CatBoost weight: 0.3
# INFO:root:  MAE: 8435.298
# INFO:root:  R²: 0.6372
# INFO:root:  RMSE: 15101.33
# INFO:root:
# Balanced (0.5/0.5):
# INFO:root:  XGB weight: 0.5, CatBoost weight: 0.5
# INFO:root:  MAE: 8443.511
# INFO:root:  R²: 0.6372
# INFO:root:  RMSE: 15102.13
# INFO:root:
# CatBoost dominant (0.3/0.7):
# INFO:root:  XGB weight: 0.3, CatBoost weight: 0.7
# INFO:root:  MAE: 8482.263
# INFO:root:  R²: 0.6345
# INFO:root:  RMSE: 15158.19
# INFO:root:
# ============================================================
# INFO:root:Best strategy: XGBoost dominant (0.7/0.3) with MAE: 8435.298
# INFO:root:============================================================
# INFO:root:
# Ensemble comparison saved to 'ensemble_comparison.csv'
# ============================================================
# Final Results (Best Strategy: XGBoost dominant (0.7/0.3))
# ============================================================
# MAE: 8435.298
# R²: 0.6372
# RMSE: 15101.33
